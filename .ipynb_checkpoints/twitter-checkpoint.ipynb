# %%
from pandas import read_csv
from datetime import datetime
from sklearn.metrics import mean_squared_error
import math

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = read_csv('DataSet.csv', header=0, index_col=0)
dataset.values
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3]
i = 1
# plot each column
pyplot.figure()
for group in groups:
    #pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(dataset.columns[group], y=1, loc='right')
    i += 1
    pyplot.show()
'''for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(dataset[:, group])
    pyplot.title(dataset.columns[group], y=1, loc='right')
    i += 1
pyplot.show()'''
print(values)
# Out:
# [[2.540e+02 8.140e+02 4.300e+01 4.000e+00]
#  [0.000e+00 2.000e+00 1.360e-01 2.000e+00]
#  [1.000e+00 0.000e+00 3.640e-02 4.000e+00]
#  ...
#  [1.375e+03 5.720e+02 4.300e+01 2.000e+00]
#  [1.200e+01 0.000e+00 1.430e+00 3.000e+00]
#  [1.700e+01 5.300e+01 1.430e+00 3.000e+00]]

# %%
values[1]
# Out:
# array([0.   , 2.   , 0.136, 2.   ])

# %%
print (dataset.head())
# Out:
#             retweet_count  favorite_count  followers_count  \
# Date_class
# 0                     254             814          43.0000
# 4                       0               2           0.1360
# 3                       1               0           0.0364
# 1                      14               0           1.4300
# 2                     685               0           0.4350
#
#             predict_class_label
# Date_class
# 0                             4
# 4                             2
# 3                             4
# 1                             4
# 2                             1

# %%
import pandas
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from pandas import DataFrame
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pandas.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
dataset = read_csv('DataSet.csv', header=0, index_col=0)
print(dataset)
values = dataset.values
print(values)
# integer encode direction
encoder = LabelEncoder()
values[:,2] = encoder.fit_transform(values[:,2])
print(values)
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
print(scaled)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[5,6,7,]], axis=1, inplace=True)
print(reframed.head())
# Out:
#             retweet_count  favorite_count  followers_count  \
# Date_class
# 0                     254             814          43.0000
# 4                       0               2           0.1360
# 3                       1               0           0.0364
# 1                      14               0           1.4300
# 2                     685               0           0.4350
# 3                       7               0           0.4350
# 1                     287            1537           6.8200
# 3                       1               4           1.4300
# 2                    1094               0           0.4350
# 0                      18               0           0.4350
# 3                      50               0           6.8200
# 0                      18               0           0.4350
# 2                      10              44           1.4300
# 0                    2576               0           6.8200
# 3                      13               0           0.0364
# 3                    4302               0           0.4350
# 0                     113               0          43.0000
# 1                      30             139           6.8200
# 2                      16               0           1.4300
# 2                    1538            2184          43.0000
# 2                     211             602          43.0000
# 4                       0              10           0.0364
# 3                      53             246           1.4300
# 0                       0               2           0.0364
# 3                      10              65           0.1360
# 3                       7              16           0.1360
# 0                     125             425           0.4350
# 3                       3              37           1.4300
# 4                       1               1           0.1360
# 4                    2733            4972          43.0000
# ...                   ...             ...              ...
# 1                       0               3           1.4300
# 3                       8             154           6.8200
# 3                       0               1           1.4300
# 3                       6              19           0.1360
# 0                     699            3942           6.8200
# 0                       0               5           1.4300
# 3                      25             211           6.8200
# 0                    7582               0           6.8200
# 0                    2456           13094          43.0000
# 3                    3700               0           0.4350
# 2                     125             319           1.4300
# 3                     207               0           1.4300
# 4                       0               0           0.1360
# 3                     328               0           0.1360
# 0                       0               2           1.4300
# 0                     870            2406           6.8200
# 1                    3894           13811           6.8200
# 3                    2236            8690          43.0000
# 1                    1031               0           0.4350
# 0                     125             659           6.8200
# 2                       4              16           1.4300
# 3                       1               0           0.0364
# 0                       0               6           1.4300
# 2                       3              23           0.0364
# 1                     189             529           0.4350
# 3                     631               0           1.4300
# 0                       4               0           1.4300
# 0                    1375             572          43.0000
# 2                      12               0           1.4300
# 2                      17              53           1.4300
#
#             predict_class_label
# Date_class
# 0                             4
# 4                             2
# 3                             4
# 1                             4
# 2                             1
# 3                             1
# 1                             2
# 3                             4
# 2                             1
# 0                             3
# 3                             1
# 0                             3
# 2                             4
# 0                             4
# 3                             4
# 3                             1
# 0                             2
# 1                             4
# 2                             1
# 2                             2
# 2                             2
# 4                             4
# 3                             3
# 0                             4
# 3                             2
# 3                             2
# 0                             4
# 3                             4
# 4                             4
# 4                             2
# ...                         ...
# 1                             2
# 3                             4
# 3                             4
# 3                             3
# 0                             4
# 0                             2
# 3                             4
# 0                             4
# 0                             2
# 3                             4
# 2                             4
# 3                             2
# 4                             2
# 3                             4
# 0                             2
# 0                             2
# 1                             3
# 3                             2
# 1                             1
# 0                             4
# 2                             4
# 3                             4
# 0                             4
# 2                             2
# 1                             3
# 3                             4
# 0                             1
# 0                             2
# 2                             3
# 2                             3
#
# [38734 rows x 4 columns]
# [[2.540e+02 8.140e+02 4.300e+01 4.000e+00]
#  [0.000e+00 2.000e+00 1.360e-01 2.000e+00]
#  [1.000e+00 0.000e+00 3.640e-02 4.000e+00]
#  ...
#  [1.375e+03 5.720e+02 4.300e+01 2.000e+00]
#  [1.200e+01 0.000e+00 1.430e+00 3.000e+00]
#  [1.700e+01 5.300e+01 1.430e+00 3.000e+00]]
# [[2.540e+02 8.140e+02 5.000e+00 4.000e+00]
#  [0.000e+00 2.000e+00 1.000e+00 2.000e+00]
#  [1.000e+00 0.000e+00 0.000e+00 4.000e+00]
#  ...
#  [1.375e+03 5.720e+02 5.000e+00 2.000e+00]
#  [1.200e+01 0.000e+00 3.000e+00 3.000e+00]
#  [1.700e+01 5.300e+01 3.000e+00 3.000e+00]]
#       var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)       var1(t)
# 1  1.530788e-04   0.000557        1.0   1.000000  0.000000e+00
# 2  0.000000e+00   0.000001        0.2   0.333333  6.026725e-07
# 3  6.026725e-07   0.000000        0.0   1.000000  8.437415e-06
# 4  8.437415e-06   0.000000        0.6   1.000000  4.128307e-04
# 5  4.128307e-04   0.000000        0.4   0.000000  4.218708e-06

# %%
print(type(dataset))
print((values))
print (float(values[0][0]))
type(values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# [[2.540e+02 8.140e+02 4.300e+01 4.000e+00]
#  [0.000e+00 2.000e+00 1.360e-01 2.000e+00]
#  [1.000e+00 0.000e+00 3.640e-02 4.000e+00]
#  ...
#  [1.375e+03 5.720e+02 4.300e+01 2.000e+00]
#  [1.200e+01 0.000e+00 1.430e+00 3.000e+00]
#  [1.700e+01 5.300e+01 1.430e+00 3.000e+00]]
# 254.0
# numpy.ndarray

# %%
dataset.values
# Out:
# array([[2.540e+02, 8.140e+02, 4.300e+01, 4.000e+00],
#        [0.000e+00, 2.000e+00, 1.360e-01, 2.000e+00],
#        [1.000e+00, 0.000e+00, 3.640e-02, 4.000e+00],
#        ...,
#        [1.375e+03, 5.720e+02, 4.300e+01, 2.000e+00],
#        [1.200e+01, 0.000e+00, 1.430e+00, 3.000e+00],
#        [1.700e+01, 5.300e+01, 1.430e+00, 3.000e+00]])

# %%
dataset.head()
# Out:
#             retweet_count  favorite_count  followers_count  \
# Date_class
# 0                     254             814          43.0000
# 4                       0               2           0.1360
# 3                       1               0           0.0364
# 1                      14               0           1.4300
# 2                     685               0           0.4350
#
#             predict_class_label
# Date_class
# 0                             4
# 4                             2
# 3                             4
# 1                             4
# 2                             1

# %%
# split into train and test sets
from sklearn.model_selection import train_test_split
values = reframed.values
X=values[:, :-1]
y=values[:, -1]

train_X, test_X, train_y , test_y = train_test_split(X, y, test_size=0.33, random_state=42)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (25951, 1, 4) (25951,) (12782, 1, 4) (12782,)

# %%
test_X.shape
# Out:
# (12782, 1, 4)

# %%
from tensorflow import keras as k
#from keras.utils.visualize_util import plot
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
# design network
model = Sequential()

model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
#model.add(Flatten())
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, validation_split=0.33,epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 25951 samples, validate on 12782 samples
# Epoch 1/50
#  - 1s - loss: 0.0015 - val_loss: 0.0010
# Epoch 2/50
#  - 1s - loss: 0.0011 - val_loss: 0.0012
# Epoch 3/50
#  - 1s - loss: 0.0011 - val_loss: 0.0011
# Epoch 4/50
#  - 1s - loss: 0.0011 - val_loss: 0.0011
# Epoch 5/50
#  - 1s - loss: 0.0010 - val_loss: 0.0011
# Epoch 6/50
#  - 1s - loss: 0.0010 - val_loss: 0.0010
# Epoch 7/50
#  - 1s - loss: 0.0011 - val_loss: 0.0013
# Epoch 8/50
#  - 1s - loss: 0.0011 - val_loss: 0.0014
# Epoch 9/50
#  - 1s - loss: 0.0010 - val_loss: 9.5781e-04
# Epoch 10/50
#  - 1s - loss: 0.0010 - val_loss: 0.0011
# Epoch 11/50
#  - 1s - loss: 9.9406e-04 - val_loss: 9.3183e-04
# Epoch 12/50
#  - 1s - loss: 0.0011 - val_loss: 8.7237e-04
# Epoch 13/50
#  - 1s - loss: 0.0010 - val_loss: 0.0011
# Epoch 14/50
#  - 1s - loss: 9.8892e-04 - val_loss: 0.0011
# Epoch 15/50
#  - 1s - loss: 0.0010 - val_loss: 8.8414e-04
# Epoch 16/50
#  - 1s - loss: 9.9560e-04 - val_loss: 8.5973e-04
# Epoch 17/50
#  - 1s - loss: 0.0011 - val_loss: 0.0017
# Epoch 18/50
#  - 1s - loss: 9.5631e-04 - val_loss: 0.0010
# Epoch 19/50
#  - 1s - loss: 0.0010 - val_loss: 8.7530e-04
# Epoch 20/50
#  - 1s - loss: 9.5948e-04 - val_loss: 9.2837e-04
# Epoch 21/50
#  - 1s - loss: 0.0011 - val_loss: 0.0011
# Epoch 22/50
#  - 1s - loss: 9.9626e-04 - val_loss: 8.4273e-04
# Epoch 23/50
#  - 1s - loss: 9.5032e-04 - val_loss: 8.6326e-04
# Epoch 24/50
#  - 1s - loss: 0.0010 - val_loss: 9.0657e-04
# Epoch 25/50
#  - 1s - loss: 9.9034e-04 - val_loss: 9.0973e-04
# Epoch 26/50
#  - 1s - loss: 0.0010 - val_loss: 0.0013
# Epoch 27/50
#  - 1s - loss: 9.8477e-04 - val_loss: 0.0011
# Epoch 28/50
#  - 1s - loss: 0.0010 - val_loss: 8.5390e-04
# Epoch 29/50
#  - 1s - loss: 9.4968e-04 - val_loss: 0.0010
# Epoch 30/50
#  - 1s - loss: 9.6719e-04 - val_loss: 9.1623e-04
# Epoch 31/50
#  - 1s - loss: 9.4506e-04 - val_loss: 9.1281e-04
# Epoch 32/50
#  - 1s - loss: 9.9053e-04 - val_loss: 9.5556e-04
# Epoch 33/50
#  - 1s - loss: 0.0010 - val_loss: 0.0015
# Epoch 34/50
#  - 1s - loss: 9.8556e-04 - val_loss: 9.2654e-04
# Epoch 35/50
#  - 1s - loss: 0.0010 - val_loss: 9.0682e-04
# Epoch 36/50
#  - 1s - loss: 9.2543e-04 - val_loss: 8.8027e-04
# Epoch 37/50
#  - 1s - loss: 9.3155e-04 - val_loss: 8.9156e-04
# Epoch 38/50
#  - 1s - loss: 9.2255e-04 - val_loss: 0.0010
# Epoch 39/50
#  - 1s - loss: 9.6764e-04 - val_loss: 0.0010
# Epoch 40/50
#  - 1s - loss: 9.2799e-04 - val_loss: 8.9825e-04
# Epoch 41/50
#  - 1s - loss: 9.2283e-04 - val_loss: 8.4501e-04
# Epoch 42/50
#  - 1s - loss: 9.4332e-04 - val_loss: 0.0012
# Epoch 43/50
#  - 1s - loss: 9.5535e-04 - val_loss: 8.4294e-04
# Epoch 44/50
#  - 1s - loss: 9.2516e-04 - val_loss: 0.0012
# Epoch 45/50
#  - 1s - loss: 9.3004e-04 - val_loss: 8.3975e-04
# Epoch 46/50
#  - 1s - loss: 9.1819e-04 - val_loss: 0.0013
# Epoch 47/50
#  - 1s - loss: 9.8582e-04 - val_loss: 8.8634e-04
# Epoch 48/50
#  - 1s - loss: 9.5669e-04 - val_loss: 0.0010
# Epoch 49/50
#  - 1s - loss: 9.2823e-04 - val_loss: 9.0856e-04
# Epoch 50/50
#  - 1s - loss: 9.2816e-04 - val_loss: 8.5506e-04

# %%
# make a prediction

yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# invert scaling for forecast
inv_yhat = pandas.concat((pandas.DataFrame(yhat), pandas.DataFrame(test_X[:, 1:])), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = pandas.concat((pandas.DataFrame(test_y), pandas.DataFrame(test_X[:, 1:])), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print ((inv_y),(inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# [ 44.99999896   2.           0.         ...   0.         758.00000962
#   11.99999962] [239.95698303 326.48434254 326.88226273 ... 306.22981842 118.31529135
#  302.44107732]
# Test RMSE: 19433.917
